# %%
#!pip install pandas
#!pip install finnhub-python
#!pip install yfinance

# %%
import os
import finnhub
import pandas as pd
import time

# Initialize Finnhub client with your API key
finnhub_client = finnhub.Client(api_key="css2cf9r01qj3u0ovmegcss2cf9r01qj3u0ovmf0")

# Define the base directory path where all data files will be saved
path = "/Users/maxwe/portfolio_optimizer/news_data"

# Define function to download and save news data for multiple companies individually
def download_news_for_multiple_companies(symbols, from_date, to_date, output_directory=path):
    # Ensure the output directory exists
    os.makedirs(output_directory, exist_ok=True)
    
    for symbol in symbols:
        try:
            # Fetch news data for each symbol
            news_data = finnhub_client.company_news(symbol, _from=from_date, to=to_date)
            
            if news_data:
                # Convert news data to DataFrame
                news_df = pd.DataFrame(news_data)
                
                # Set the file path for each individual company's data
                output_file = os.path.join(output_directory, f"{symbol}_news.csv")
                
                # Save each company's data to its own CSV file
                news_df.to_csv(output_file, index=False)
                print(f"Data for {symbol} saved to {output_file}")
            else:
                print(f"No data available for {symbol} in the specified date range.")
            
            # Optional: Pause to avoid hitting API rate limits
            time.sleep(1)  # Adjust sleep time based on API rate limits
        except Exception as e:
            print(f"An error occurred for {symbol}: {e}")

# Example usage
company_symbols = ["AAPL", "MSFT", "GOOGL", "AMZN", "TSLA"]
from_date = "2023-12-01"
to_date = "2024-11-17"
download_news_for_multiple_companies(company_symbols, from_date, to_date)
# Out:
# Data for AAPL saved to /Users/maxwe/portfolio_optimizer/news_data/AAPL_news.csv
# Data for MSFT saved to /Users/maxwe/portfolio_optimizer/news_data/MSFT_news.csv
# Data for GOOGL saved to /Users/maxwe/portfolio_optimizer/news_data/GOOGL_news.csv
# Data for AMZN saved to /Users/maxwe/portfolio_optimizer/news_data/AMZN_news.csv
# Data for TSLA saved to /Users/maxwe/portfolio_optimizer/news_data/TSLA_news.csv

# %%
import pandas as pd

# Define the unique paths to each company's news data CSV file
aapl_news_path = path + "/AAPL_news.csv"
msft_news_path = path + "/MSFT_news.csv"
googl_news_path = path + "/GOOGL_news.csv"
amzn_news_path = path + "/AMZN_news.csv"
tsla_news_path = path + "/TSLA_news.csv"

# %%
# Load each CSV file as a Pandas DataFrame
aapl_df = pd.read_csv(aapl_news_path)
msft_df = pd.read_csv(msft_news_path)
googl_df = pd.read_csv(googl_news_path)
amzn_df = pd.read_csv(amzn_news_path)
tsla_df = pd.read_csv(tsla_news_path)

# %%
aapl_df.head()
# Out:
#   category    datetime                                           headline  \
# 0  company  1731861041  IBM CEO on Trump: ‘Less regulation, more innov...
# 1  company  1731856400  Analyst: Apple (AAPL)’s iPhone Sell-Throughs ‘...
# 2  company  1731835800  STK: A Technology Equity Fund With Call Overwr...
# 3  company  1731828384  Tata seals deal with Pegatron for iPhone plant...
# 4  company  1731819660  China’s smartphone makers head upmarket in Eur...
#
#           id                                              image related  \
# 0  131411474                                                NaN    AAPL
# 1  131411475  https://s.yimg.com/ny/api/res/1.2/e1QwhqQiBt5e...    AAPL
# 2  131410145  https://static.seekingalpha.com/cdn/s3/uploads...    AAPL
# 3  131408365  https://media.zenfs.com/en/reuters-finance.com...    AAPL
# 4  131404195  https://s.yimg.com/cv/apiv2/social/images/yaho...    AAPL
#
#          source                                            summary  \
# 0         Yahoo  Tech executives may be warming to President-el...
# 1         Yahoo  We recently published a list of 10 AI Stocks t...
# 2  SeekingAlpha  Discover why STK is a solid investment for inc...
# 3         Yahoo  India's Tata Electronics has agreed to buy a m...
# 4         Yahoo  Chinese smartphone manufacturers are intensify...
#
#                                                  url
# 0  https://finnhub.io/api/news?id=b4f6822d195b9ae...
# 1  https://finnhub.io/api/news?id=54c311ce2c806c0...
# 2  https://finnhub.io/api/news?id=5e857f9d2489713...
# 3  https://finnhub.io/api/news?id=ca7d6af4e9ddf57...
# 4  https://finnhub.io/api/news?id=6d2ce466b7c42d1...

# %%
# Start with the original DataFrame, aapl_df
# Rename columns first in aapl_df
aapl_df = aapl_df.rename(columns={'headline': 'title', 'datetime': 'date', 'related': 'stock'})

# Now select specific columns and make a copy
df = aapl_df[['title', 'date', 'stock']].copy()

df.head()
# Out:
#                                                title        date stock
# 0  IBM CEO on Trump: ‘Less regulation, more innov...  1731861041  AAPL
# 1  Analyst: Apple (AAPL)’s iPhone Sell-Throughs ‘...  1731856400  AAPL
# 2  STK: A Technology Equity Fund With Call Overwr...  1731835800  AAPL
# 3  Tata seals deal with Pegatron for iPhone plant...  1731828384  AAPL
# 4  China’s smartphone makers head upmarket in Eur...  1731819660  AAPL

# %%
# Define a reasonable range for Unix timestamps (between 1970-01-01 and a future date within bounds)
min_valid_timestamp = 0              # Start of Unix epoch (1970-01-01)
max_valid_timestamp = 2147483647      # Roughly represents dates up to 2038-01-19

# Filter out-of-bounds dates
df = df[(df['date'] >= min_valid_timestamp) & (df['date'] <= max_valid_timestamp)]

# %%
import datetime as dt

# %%
# Convert 'date' column from Unix timestamp to datetime
df['date'] = pd.to_datetime(df['date'], unit='s')

# Function to remove timezone information
def localize_time(date):
    return date.tz_localize(None)

# Remove timezone info
df['date'] = df['date'].apply(localize_time)

# Extract 'time' and 'day' parts
df['time'] = df['date'].apply(lambda x: x.time())
df['day'] = df['date'].apply(lambda x: x.date())

# %%
df.head()
# Out:
#                                                title                date  \
# 0  IBM CEO on Trump: ‘Less regulation, more innov... 2024-11-17 16:30:41
# 1  Analyst: Apple (AAPL)’s iPhone Sell-Throughs ‘... 2024-11-17 15:13:20
# 2  STK: A Technology Equity Fund With Call Overwr... 2024-11-17 09:30:00
# 3  Tata seals deal with Pegatron for iPhone plant... 2024-11-17 07:26:24
# 4  China’s smartphone makers head upmarket in Eur... 2024-11-17 05:01:00
#
#   stock      time         day
# 0  AAPL  16:30:41  2024-11-17
# 1  AAPL  15:13:20  2024-11-17
# 2  AAPL  09:30:00  2024-11-17
# 3  AAPL  07:26:24  2024-11-17
# 4  AAPL  05:01:00  2024-11-17

# %%
market_open = dt.time(9, 30, 0)
market_close = dt.time(16, 0, 0)

import yfinance as yf

aapl_price = yf.download("AAPL", start="2023-12-01", end="2024-11-17")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
nvda_price.head()
# Out:
# Price                     Adj Close    Close     High      Low     Open  \
# Ticker                         NVDA     NVDA     NVDA     NVDA     NVDA
# Date
# 2011-01-03 00:00:00+00:00  0.362732  0.39550  0.39925  0.38750  0.38800
# 2011-01-04 00:00:00+00:00  0.361586  0.39425  0.39800  0.38550  0.39625
# 2011-01-05 00:00:00+00:00  0.389329  0.42450  0.42500  0.39750  0.40150
# 2011-01-06 00:00:00+00:00  0.443212  0.48325  0.48350  0.43425  0.43550
# 2011-01-07 00:00:00+00:00  0.455593  0.49675  0.49825  0.46700  0.47775
#
# Price                          Volume
# Ticker                           NVDA
# Date
# 2011-01-03 00:00:00+00:00   817448000
# 2011-01-04 00:00:00+00:00   651384000
# 2011-01-05 00:00:00+00:00  1428216000
# 2011-01-06 00:00:00+00:00  3493312000
# 2011-01-07 00:00:00+00:00  2579984000

# %%
# Ensure the index is a datetime type
aapl_price.index = pd.to_datetime(aapl_price.index)

# Strip the time and timezone, leaving only the date
aapl_price.index = aapl_price.index.normalize()  # Removes time, keeps only the date part

# For what we are looking at, we only need the "Open" and "Adj Close" columns
aapl = aapl_price[['Open', 'Adj Close']].copy()

# If there are multiple levels in the column names, flatten them by renaming
aapl.columns = ['Open', 'Adj Close']

# %%
aapl.head()
# Out:
#                   Open   Adj Close
# 2023-12-01  190.330002  190.307693
# 2023-12-04  189.979996  188.506500
# 2023-12-05  190.210007  192.477051
# 2023-12-06  194.449997  191.382416
# 2023-12-07  193.630005  193.322906

# %%
# We also need to make sure that the Date index in this dataframe is a datetime.date
# object so that we can compare it with our ['day'] column in the dataframe with out data

aapl.index = aapl.index.to_series().apply(get_day)

# %%
# Lets check our index type now to see make sure that it is a datetime.date object so that we
# can use ti for the correct comparisons

type(aapl.index[0])
# Out:
# datetime.date

# %%
from datetime import timedelta

def price_change_for_one_day(day, time, aapl):
    # Check if the day is a trading day in the `aapl` index
    if day in aapl.index:
        # Case: Before market close
        if time < market_close:
            dollar_change = aapl.loc[day]['Adj Close'] - aapl.loc[day]['Open']
            pct_change = dollar_change / aapl.loc[day]['Open']
        else:  # After market close
            close_price = aapl.loc[day]['Adj Close']
            next_day = day + timedelta(days=1)
            
            # Find the next trading day, stopping if we go past available dates
            while next_day not in aapl.index:
                next_day += timedelta(days=1)
                if next_day > aapl.index[-1]:  # No next trading day available
                    return None
            
            next_day_open = aapl.loc[next_day]['Open']
            pct_change = (next_day_open - close_price) / close_price
    
    else:  # Non-trading day case
        next_day = day + timedelta(days=1)
        
        # Find the next trading day
        while next_day not in aapl.index:
            next_day += timedelta(days=1)
            if next_day > aapl.index[-1]:  # No next trading day available
                return None
        
        previous_day = day - timedelta(days=1)
        
        # Find the previous trading day
        while previous_day not in aapl.index:
            previous_day -= timedelta(days=1)
            if previous_day < aapl.index[0]:  # No previous trading day available
                return None

        next_day_open = aapl.loc[next_day]['Open']
        previous_day_close = aapl.loc[previous_day]['Adj Close']
        pct_change = (next_day_open - previous_day_close) / previous_day_close

    return pct_change * 100 if pct_change is not None else None

# %%
# We apply this function to the dataframe and sort the price changes in a new column called pct_change

df['pct_change'] = df.apply(lambda row: price_change_for_one_day(row['day'], row['time'], aapl), axis=1)

# %%
# Display the first 20 rows of the DataFrame
df.head(50)
# Out:
#                                                 title                date  \
# 0   IBM CEO on Trump: ‘Less regulation, more innov... 2024-11-17 16:30:41
# 1   Analyst: Apple (AAPL)’s iPhone Sell-Throughs ‘... 2024-11-17 15:13:20
# 2   STK: A Technology Equity Fund With Call Overwr... 2024-11-17 09:30:00
# 3   Tata seals deal with Pegatron for iPhone plant... 2024-11-17 07:26:24
# 4   China’s smartphone makers head upmarket in Eur... 2024-11-17 05:01:00
# 5   Qualcomm Q4: Look Beyond Short-Term Headwinds,... 2024-11-17 03:09:14
# 6           How To Earn $500 A Month From Apple Stock 2024-11-16 15:00:13
# 7   Nvidia, Meta, Apple, and Microsoft Could Help ... 2024-11-16 10:21:00
# 8   Prediction: This Warren Buffett Stock Will Out... 2024-11-16 10:05:00
# 9   Will Trump’s tariffs cause price hikes in elec... 2024-11-16 09:32:00
# 10  Meet the Stock-Split Stock That Soared by 11,2... 2024-11-16 09:32:00
# 11  Nvidia Has 65% of Its Portfolio Invested in 1 ... 2024-11-16 08:55:00
# 12  Yes, stocks are crazy expensive right now. The... 2024-11-16 07:00:00
# 13  AST SpaceMobile Could Revolutionize Cellphone ... 2024-11-15 20:30:18
# 14  Apple Inc. (AAPL): Among the Best Metaverse St... 2024-11-15 19:37:46
# 15           Apple, Gen Z on personal finance: Wealth 2024-11-15 19:13:56
# 16  Apple Removes Russian-Language RFE/RL App Foll... 2024-11-15 18:53:32
# 17   Stocks fall, growth in e-commerce: Morning Brief 2024-11-15 18:38:23
# 18  S&P revises Ireland's outlook to 'positive' on... 2024-11-15 17:49:33
# 19  Trump Promises Tariffs. Wall Street Is Debatin... 2024-11-15 17:43:00
# 20  Why Has Warren Buffett Been Selling So Much St... 2024-11-15 17:31:53
# 21  Inflation Isn’t Dead Yet. The Post-Election Ra... 2024-11-15 17:11:00
# 22  Berkshire Hathaway Sells $23B in Apple Shares,... 2024-11-15 17:02:42
# 23  Trump's China tariff could cost Apple $256 per... 2024-11-15 16:39:39
# 24  Stocks to watch next week: Nvidia, Walmart, Im... 2024-11-15 16:33:08
# 25  Apple Inc. stock outperforms competitors despi... 2024-11-15 16:32:00
# 26  Apple deletes US-funded RFE/RL news app from R... 2024-11-15 16:15:37
# 27  Warren Buffett Bought And Sold These Stocks In Q3 2024-11-15 16:08:29
# 28  $99 Billion Bet: Warren Buffett Invests Heavil... 2024-11-15 15:45:33
# 29  Big Tech Traders Are in Wait-and-See Mode on T... 2024-11-15 10:35:29
# 30  Amazon, Apple stocks waver as hedge funds trim... 2024-11-15 14:51:50
# 31  Futures, hedge funds pull back in Big Tech, Te... 2024-11-15 14:36:47
# 32  Apple Inc (AAPL) Unveils Final Cut Pro 11: AI-... 2024-11-15 14:26:13
# 33  Trump, tariffs, and one unpredictable economy ... 2024-11-15 14:20:31
# 34  Calculating The Fair Value Of Apple Inc. (NASD... 2024-11-15 14:00:14
# 35        Alibaba: Strong Results And Its Cheap Again 2024-11-15 12:03:01
# 36  Alibaba's Fiscal Q2 2025 Earnings Underpin 3 I... 2024-11-15 11:10:26
# 37  Nasdaq heads for fourth day in the red as tech... 2024-11-15 10:29:17
# 38  Nvidia: The Unstoppable Train Approaching The ... 2024-11-15 10:01:00
# 39  How To Invest $100,000 In Large Cap Stocks: A ... 2024-11-15 09:57:38
# 40  Magnificent 7 Are Alive And Well, But A Rest I... 2024-11-15 07:30:00
# 41              Domino's and Pool boom on Buffett buy 2024-11-15 06:13:05
# 42  Berkshire Hathaway Takes Stake in Domino’s Piz... 2024-11-15 04:48:00
# 43  Li Lu's Strategic Moves in Q3 2024: A Closer L... 2024-11-15 02:14:53
# 44  Buffett Watch: Sell Your Overvalued Apple Stoc... 2024-11-15 02:00:41
# 45         Fidelity OTC Portfolio Fund Q2 2024 Review 2024-11-15 01:35:00
# 46  A Little-Known Company Is Worth $100 Billion. ... 2024-11-15 01:15:00
# 47  Buffett's Berkshire Buys Shares of Domino's Pi... 2024-11-14 23:50:33
# 48  Evercore ISI Maintains “Outperform” Rating on ... 2024-11-14 22:58:31
# 49  Warren Buffett's Strategic Moves in Q3 2024: A... 2024-11-14 22:53:17
#
#    stock      time         day  pct_change
# 0   AAPL  16:30:41  2024-11-17         NaN
# 1   AAPL  15:13:20  2024-11-17         NaN
# 2   AAPL  09:30:00  2024-11-17         NaN
# 3   AAPL  07:26:24  2024-11-17         NaN
# 4   AAPL  05:01:00  2024-11-17         NaN
# 5   AAPL  03:09:14  2024-11-17         NaN
# 6   AAPL  15:00:13  2024-11-16         NaN
# 7   AAPL  10:21:00  2024-11-16         NaN
# 8   AAPL  10:05:00  2024-11-16         NaN
# 9   AAPL  09:32:00  2024-11-16         NaN
# 10  AAPL  09:32:00  2024-11-16         NaN
# 11  AAPL  08:55:00  2024-11-16         NaN
# 12  AAPL  07:00:00  2024-11-16         NaN
# 13  AAPL  20:30:18  2024-11-15         NaN
# 14  AAPL  19:37:46  2024-11-15         NaN
# 15  AAPL  19:13:56  2024-11-15         NaN
# 16  AAPL  18:53:32  2024-11-15         NaN
# 17  AAPL  18:38:23  2024-11-15         NaN
# 18  AAPL  17:49:33  2024-11-15         NaN
# 19  AAPL  17:43:00  2024-11-15         NaN
# 20  AAPL  17:31:53  2024-11-15         NaN
# 21  AAPL  17:11:00  2024-11-15         NaN
# 22  AAPL  17:02:42  2024-11-15         NaN
# 23  AAPL  16:39:39  2024-11-15         NaN
# 24  AAPL  16:33:08  2024-11-15         NaN
# 25  AAPL  16:32:00  2024-11-15         NaN
# 26  AAPL  16:15:37  2024-11-15         NaN
# 27  AAPL  16:08:29  2024-11-15         NaN
# 28  AAPL  15:45:33  2024-11-15   -0.618372
# 29  AAPL  10:35:29  2024-11-15   -0.618372
# 30  AAPL  14:51:50  2024-11-15   -0.618372
# 31  AAPL  14:36:47  2024-11-15   -0.618372
# 32  AAPL  14:26:13  2024-11-15   -0.618372
# 33  AAPL  14:20:31  2024-11-15   -0.618372
# 34  AAPL  14:00:14  2024-11-15   -0.618372
# 35  AAPL  12:03:01  2024-11-15   -0.618372
# 36  AAPL  11:10:26  2024-11-15   -0.618372
# 37  AAPL  10:29:17  2024-11-15   -0.618372
# 38  AAPL  10:01:00  2024-11-15   -0.618372
# 39  AAPL  09:57:38  2024-11-15   -0.618372
# 40  AAPL  07:30:00  2024-11-15   -0.618372
# 41  AAPL  06:13:05  2024-11-15   -0.618372
# 42  AAPL  04:48:00  2024-11-15   -0.618372
# 43  AAPL  02:14:53  2024-11-15   -0.618372
# 44  AAPL  02:00:41  2024-11-15   -0.618372
# 45  AAPL  01:35:00  2024-11-15   -0.618372
# 46  AAPL  01:15:00  2024-11-15   -0.618372
# 47  AAPL  23:50:33  2024-11-14   -0.797479
# 48  AAPL  22:58:31  2024-11-14   -0.797479
# 49  AAPL  22:53:17  2024-11-14   -0.797479
